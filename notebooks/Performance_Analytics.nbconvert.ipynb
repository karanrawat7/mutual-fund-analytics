# %% [markdown]
# # Performance Analytics Notebook
# ### Mutual Fund Quantitative Analysis — 40 Schemes (2021 – 2026)
#
# **Coverage:** Daily Returns · CAGR (1y/3y/5yr) · Sharpe Ratio · Sortino Ratio · Alpha & Beta (OLS) · Maximum Drawdown · Fund Scorecard · Benchmark Comparison · Tracking Error
#
# **Risk-Free Rate:** 6.5% (RBI Repo Rate Proxy)
# **Benchmark:** Nifty 50 & Nifty 100
# **Universe:** 40 synthetic AMFI schemes across Equity / Debt / Hybrid

# %% [markdown]
# ## 1. Setup & Data Loading

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px
from scipy import stats
import sqlite3, os

sns.set_theme(style="darkgrid")
plt.rcParams["figure.figsize"] = (14, 6)
plt.rcParams["font.size"] = 11

DB_PATH = os.path.join("..", "database", "bluestock_mf.db")
conn = sqlite3.connect(DB_PATH)

df_metrics    = pd.read_csv(os.path.join("..", "data", "processed", "fund_metrics.csv"))
df_nav        = pd.read_sql("SELECT * FROM fact_nav_synthetic",  conn)
df_benchmarks = pd.read_sql("SELECT * FROM fact_benchmarks",     conn)
df_schemes    = pd.read_sql("SELECT * FROM dim_fund_synthetic",  conn)
conn.close()

df_nav["date"]        = pd.to_datetime(df_nav["date"])
df_benchmarks["date"] = pd.to_datetime(df_benchmarks["date"])
print(f"Loaded {len(df_schemes)} schemes | {len(df_nav):,} NAV rows | {len(df_metrics)} fund metric rows")
# Out:
# Loaded 40 schemes | 57,320 NAV rows | 40 fund metric rows

# %% [markdown]
# ## 2. Daily Returns — Distribution Validation
# `daily_return = NAV_t / NAV_{t-1} - 1`
#
# We compute returns for every fund-day, then overlay a normal distribution to confirm the return series behaves reasonably (slight negative skew expected for equity funds).

# %%
# Compute daily returns for all 40 schemes
df_nav_sorted = df_nav.sort_values(["amfi_code", "date"])
df_nav_sorted["daily_return"] = df_nav_sorted.groupby("amfi_code")["nav"].pct_change()
df_returns = df_nav_sorted.dropna(subset=["daily_return"])

# Summary
print("Daily Return Summary (all funds pooled):")
print(df_returns["daily_return"].describe().apply(lambda x: f"{x:.6f}"))

# Distribution plot (sample 50k rows for speed)
sample = df_returns["daily_return"].sample(min(50_000, len(df_returns)), random_state=42)
fig, ax = plt.subplots(figsize=(13, 5))
ax.hist(sample * 100, bins=200, density=True, color="#1565C0", alpha=0.75, label="Observed daily returns")

# Overlay Normal
mu, sigma = sample.mean() * 100, sample.std() * 100
x = np.linspace(mu - 4*sigma, mu + 4*sigma, 400)
from scipy.stats import norm
ax.plot(x, norm.pdf(x, mu, sigma), "r--", lw=2, label=f"Normal(μ={mu:.3f}%, σ={sigma:.3f}%)")
ax.axvline(0, color="white", lw=0.8, linestyle=":")
ax.set_xlabel("Daily Return (%)"); ax.set_ylabel("Density")
ax.set_title("Daily Return Distribution — All 40 Schemes Pooled")
ax.legend()
plt.tight_layout(); plt.show()
# Out:
# Daily Return Summary (all funds pooled):
# count    57280.000000
# mean         0.000504
# std          0.010467
# min         -0.064811
# 25%         -0.004010
# 50%          0.000370
# 75%          0.004998
# max          0.062385
# Name: daily_return, dtype: str

# %% [markdown]
# ## 3. CAGR Comparison Table
# `CAGR = (NAV_end / NAV_start) ^ (1 / n) − 1`
#
# We calculate 1-year, 3-year, and 5-year CAGR and display a ranked table, sorted by 3-year CAGR.

# %%
cagr_cols = ["scheme_name", "category", "cagr_1y", "cagr_3y", "cagr_5y", "expense_ratio"]
df_cagr = df_metrics[cagr_cols].sort_values("cagr_3y", ascending=False).reset_index(drop=True)
df_cagr.index += 1
df_cagr.index.name = "rank"

# Style the table
def color_val(v):
    if isinstance(v, float):
        color = "green" if v > 0 else "red"
        return f"color: {color}"
    return ""

styled = (df_cagr.style
          .background_gradient(subset=["cagr_1y","cagr_3y","cagr_5y"], cmap="RdYlGn")
          .format({"cagr_1y": "{:.2f}%", "cagr_3y": "{:.2f}%", "cagr_5y": "{:.2f}%",
                   "expense_ratio": "{:.2f}%"}))
styled
# Out:
# <style type="text/css">
# #T_103d1_row0_col2 {
#   background-color: #82c966;
#   color: #000000;
# }
# #T_103d1_row0_col3, #T_103d1_row11_col2, #T_103d1_row13_col4 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_103d1_row0_col4 {
#   background-color: #91d068;
#   color: #000000;
# }
# #T_103d1_row1_col2, #T_103d1_row12_col3 {
#   background-color: #fffab6;
#   color: #000000;
# }
# #T_103d1_row1_col3 {
#   background-color: #0c7f43;
#   color: #f1f1f1;
# }
# #T_103d1_row1_col4 {
#   background-color: #b9e176;
#   color: #000000;
# }
# #T_103d1_row2_col2 {
#   background-color: #bbe278;
#   color: #000000;
# }
# #T_103d1_row2_col3 {
#   background-color: #54b45f;
#   color: #f1f1f1;
# }
# #T_103d1_row2_col4, #T_103d1_row16_col2 {
#   background-color: #e5f49b;
#   color: #000000;
# }
# #T_103d1_row3_col2 {
#   background-color: #a7d96b;
#   color: #000000;
# }
# #T_103d1_row3_col3 {
#   background-color: #57b65f;
#   color: #f1f1f1;
# }
# #T_103d1_row3_col4 {
#   background-color: #dcf08f;
#   color: #000000;
# }
# #T_103d1_row4_col2 {
#   background-color: #d1ec86;
#   color: #000000;
# }
# #T_103d1_row4_col3 {
#   background-color: #78c565;
#   color: #000000;
# }
# #T_103d1_row4_col4, #T_103d1_row6_col3 {
#   background-color: #a2d76a;
#   color: #000000;
# }
# #T_103d1_row5_col2 {
#   background-color: #afdd70;
#   color: #000000;
# }
# #T_103d1_row5_col3, #T_103d1_row6_col4 {
#   background-color: #a0d669;
#   color: #000000;
# }
# #T_103d1_row5_col4 {
#   background-color: #8ecf67;
#   color: #000000;
# }
# #T_103d1_row6_col2 {
#   background-color: #e9f6a1;
#   color: #000000;
# }
# #T_103d1_row7_col2 {
#   background-color: #097940;
#   color: #f1f1f1;
# }
# #T_103d1_row7_col3, #T_103d1_row17_col4 {
#   background-color: #a5d86a;
#   color: #000000;
# }
# #T_103d1_row7_col4, #T_103d1_row13_col2 {
#   background-color: #bde379;
#   color: #000000;
# }
# #T_103d1_row8_col2 {
#   background-color: #fee593;
#   color: #000000;
# }
# #T_103d1_row8_col3 {
#   background-color: #e6f59d;
#   color: #000000;
# }
# #T_103d1_row8_col4, #T_103d1_row10_col2 {
#   background-color: #cfeb85;
#   color: #000000;
# }
# #T_103d1_row9_col2, #T_103d1_row27_col2 {
#   background-color: #fee999;
#   color: #000000;
# }
# #T_103d1_row9_col3, #T_103d1_row14_col2 {
#   background-color: #ebf7a3;
#   color: #000000;
# }
# #T_103d1_row9_col4, #T_103d1_row20_col4, #T_103d1_row22_col3, #T_103d1_row26_col4 {
#   background-color: #fdb768;
#   color: #000000;
# }
# #T_103d1_row10_col3 {
#   background-color: #ecf7a6;
#   color: #000000;
# }
# #T_103d1_row10_col4 {
#   background-color: #fff1a8;
#   color: #000000;
# }
# #T_103d1_row11_col3 {
#   background-color: #feffbe;
#   color: #000000;
# }
# #T_103d1_row11_col4 {
#   background-color: #e2f397;
#   color: #000000;
# }
# #T_103d1_row12_col2, #T_103d1_row19_col3 {
#   background-color: #fed07e;
#   color: #000000;
# }
# #T_103d1_row12_col4 {
#   background-color: #0e8245;
#   color: #f1f1f1;
# }
# #T_103d1_row13_col3, #T_103d1_row19_col4, #T_103d1_row26_col2 {
#   background-color: #fff6b0;
#   color: #000000;
# }
# #T_103d1_row14_col3 {
#   background-color: #feec9f;
#   color: #000000;
# }
# #T_103d1_row14_col4 {
#   background-color: #f5fbb2;
#   color: #000000;
# }
# #T_103d1_row15_col2, #T_103d1_row33_col4 {
#   background-color: #fff3ac;
#   color: #000000;
# }
# #T_103d1_row15_col3, #T_103d1_row19_col2, #T_103d1_row24_col2 {
#   background-color: #feeb9d;
#   color: #000000;
# }
# #T_103d1_row15_col4, #T_103d1_row31_col2 {
#   background-color: #fee797;
#   color: #000000;
# }
# #T_103d1_row16_col3 {
#   background-color: #feea9b;
#   color: #000000;
# }
# #T_103d1_row16_col4 {
#   background-color: #eff8aa;
#   color: #000000;
# }
# #T_103d1_row17_col2 {
#   background-color: #f4fab0;
#   color: #000000;
# }
# #T_103d1_row17_col3, #T_103d1_row24_col4 {
#   background-color: #fee28f;
#   color: #000000;
# }
# #T_103d1_row18_col2, #T_103d1_row20_col2 {
#   background-color: #fff7b2;
#   color: #000000;
# }
# #T_103d1_row18_col3, #T_103d1_row34_col2 {
#   background-color: #fed481;
#   color: #000000;
# }
# #T_103d1_row18_col4, #T_103d1_row27_col4, #T_103d1_row39_col4 {
#   background-color: #fede89;
#   color: #000000;
# }
# #T_103d1_row20_col3, #T_103d1_row32_col2 {
#   background-color: #feca79;
#   color: #000000;
# }
# #T_103d1_row21_col2 {
#   background-color: #feeda1;
#   color: #000000;
# }
# #T_103d1_row21_col3 {
#   background-color: #fdc574;
#   color: #000000;
# }
# #T_103d1_row21_col4, #T_103d1_row23_col3 {
#   background-color: #fdb365;
#   color: #000000;
# }
# #T_103d1_row22_col2 {
#   background-color: #fbfdba;
#   color: #000000;
# }
# #T_103d1_row22_col4 {
#   background-color: #fdaf62;
#   color: #000000;
# }
# #T_103d1_row23_col2, #T_103d1_row37_col4 {
#   background-color: #fee491;
#   color: #000000;
# }
# #T_103d1_row23_col4, #T_103d1_row32_col4 {
#   background-color: #fca55d;
#   color: #000000;
# }
# #T_103d1_row24_col3 {
#   background-color: #fdb163;
#   color: #000000;
# }
# #T_103d1_row25_col2, #T_103d1_row34_col4 {
#   background-color: #fdc776;
#   color: #000000;
# }
# #T_103d1_row25_col3 {
#   background-color: #fca85e;
#   color: #000000;
# }
# #T_103d1_row25_col4, #T_103d1_row36_col2 {
#   background-color: #d7ee8a;
#   color: #000000;
# }
# #T_103d1_row26_col3, #T_103d1_row29_col4 {
#   background-color: #fa9b58;
#   color: #000000;
# }
# #T_103d1_row27_col3 {
#   background-color: #f99355;
#   color: #000000;
# }
# #T_103d1_row28_col2 {
#   background-color: #feefa3;
#   color: #000000;
# }
# #T_103d1_row28_col3, #T_103d1_row33_col2 {
#   background-color: #f88c51;
#   color: #f1f1f1;
# }
# #T_103d1_row28_col4 {
#   background-color: #fcaa5f;
#   color: #000000;
# }
# #T_103d1_row29_col2 {
#   background-color: #fed683;
#   color: #000000;
# }
# #T_103d1_row29_col3 {
#   background-color: #f88950;
#   color: #f1f1f1;
# }
# #T_103d1_row30_col2 {
#   background-color: #fee08b;
#   color: #000000;
# }
# #T_103d1_row30_col3, #T_103d1_row31_col3 {
#   background-color: #f7814c;
#   color: #f1f1f1;
# }
# #T_103d1_row30_col4 {
#   background-color: #fb9d59;
#   color: #000000;
# }
# #T_103d1_row31_col4 {
#   background-color: #f99153;
#   color: #000000;
# }
# #T_103d1_row32_col3 {
#   background-color: #f67f4b;
#   color: #f1f1f1;
# }
# #T_103d1_row33_col3, #T_103d1_row37_col2 {
#   background-color: #f57245;
#   color: #f1f1f1;
# }
# #T_103d1_row34_col3 {
#   background-color: #e65036;
#   color: #f1f1f1;
# }
# #T_103d1_row35_col2 {
#   background-color: #d93429;
#   color: #f1f1f1;
# }
# #T_103d1_row35_col3 {
#   background-color: #e14430;
#   color: #f1f1f1;
# }
# #T_103d1_row35_col4 {
#   background-color: #fece7c;
#   color: #000000;
# }
# #T_103d1_row36_col3 {
#   background-color: #d83128;
#   color: #f1f1f1;
# }
# #T_103d1_row36_col4, #T_103d1_row38_col2, #T_103d1_row39_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_103d1_row37_col3 {
#   background-color: #d62f27;
#   color: #f1f1f1;
# }
# #T_103d1_row38_col3 {
#   background-color: #c01a27;
#   color: #f1f1f1;
# }
# #T_103d1_row38_col4 {
#   background-color: #fdad60;
#   color: #000000;
# }
# #T_103d1_row39_col2 {
#   background-color: #fec877;
#   color: #000000;
# }
# </style>
# <table id="T_103d1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_103d1_level0_col0" class="col_heading level0 col0" >scheme_name</th>
#       <th id="T_103d1_level0_col1" class="col_heading level0 col1" >category</th>
#       <th id="T_103d1_level0_col2" class="col_heading level0 col2" >cagr_1y</th>
#       <th id="T_103d1_level0_col3" class="col_heading level0 col3" >cagr_3y</th>
#       <th id="T_103d1_level0_col4" class="col_heading level0 col4" >cagr_5y</th>
#       <th id="T_103d1_level0_col5" class="col_heading level0 col5" >expense_ratio</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >rank</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_103d1_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_103d1_row0_col0" class="data row0 col0" >Axis Sectoral Fund - Direct</td>
#       <td id="T_103d1_row0_col1" class="data row0 col1" >Equity</td>
#       <td id="T_103d1_row0_col2" class="data row0 col2" >26.90%</td>
#       <td id="T_103d1_row0_col3" class="data row0 col3" >29.45%</td>
#       <td id="T_103d1_row0_col4" class="data row0 col4" >21.73%</t

# %% [markdown]
# ## 4. Sharpe Ratio Ranking
# `Sharpe = (Rp − Rf) / σ(Rp) × √252`  |  Rf = 6.5% p.a.
#
# Higher Sharpe means better risk-adjusted performance. We plot the top 20 and bottom 5 for context.

# %%
df_sharpe = df_metrics[["scheme_name","category","sharpe_ratio","sortino_ratio"]].sort_values("sharpe_ratio", ascending=False).reset_index(drop=True)
df_sharpe.index += 1

# Bar chart — Top 20 by Sharpe
top20 = df_sharpe.head(20)
colors = ["#1976D2" if c == "Equity" else "#388E3C" if c == "Hybrid" else "#F57C00"
          for c in top20["category"]]

fig, ax = plt.subplots(figsize=(14, 6))
bars = ax.barh(range(len(top20)), top20["sharpe_ratio"], color=colors)
ax.set_yticks(range(len(top20)))
ax.set_yticklabels([n[:45] for n in top20["scheme_name"]], fontsize=9)
ax.axvline(0, color="red", lw=0.8, linestyle="--")
ax.set_xlabel("Sharpe Ratio")
ax.set_title("Top 20 Funds by Sharpe Ratio (annualised, Rf=6.5%)")
patches = [mpatches.Patch(color="#1976D2", label="Equity"),
           mpatches.Patch(color="#388E3C", label="Hybrid"),
           mpatches.Patch(color="#F57C00", label="Debt")]
ax.legend(handles=patches, loc="lower right")
ax.invert_yaxis()
plt.tight_layout(); plt.show()

print("\nFull Sharpe/Sortino Table:")
df_sharpe.head(40)
# Out:
# Full Sharpe/Sortino Table:
#                                     scheme_name category  sharpe_ratio  \
# 1                    DSP Sectoral Fund - Direct   Equity        1.2056
# 2        ICICI Balanced Advantage Fund - Direct   Hybrid        0.9740
# 3                   Tata Sectoral Fund - Direct   Equity        0.9541
# 4          UTI Balanced Advantage Fund - Direct   Hybrid        0.9211
# 5             HDFC Corporate Bond Fund - Direct     Debt        0.8931
# 6           DSP Aggressive Hybrid Fund - Direct   Hybrid        0.8927
# 7           UTI Aggressive Hybrid Fund - Direct   Hybrid        0.8713
# 8        Aditya Aggressive Hybrid Fund - Direct   Hybrid        0.8565
# 9                   Axis Sectoral Fund - Direct   Equity        0.8136
# 10        HDFC Balanced Advantage Fund - Direct   Hybrid        0.6901
# 11                Aditya Sectoral Fund - Direct   Equity        0.5688
# 12                Kotak Small Cap Fund - Direct   Equity        0.5484
# 13        ICICI Aggressive Hybrid Fund - Direct   Hybrid        0.5460
# 14                   HDFC Mid Cap Fund - Direct   Equity        0.5165
# 15                 Nippon Mid Cap Fund - Direct   Equity        0.5139
# 16                 Nippon Mid Cap Fund - Direct   Equity        0.5111
# 17               Nippon Gilt Fund Fund - Direct     Debt        0.5022
# 18                  UTI Small Cap Fund - Direct   Equity        0.4601
# 19                 Tata Large Cap Fund - Direct   Equity        0.4511
# 20                ICICI Large Cap Fund - Direct   Equity        0.4248
# 21                  DSP Gilt Fund Fund - Direct     Debt        0.4008
# 22             Aditya Liquid Fund Fund - Direct     Debt        0.3709
# 23          SBI Aggressive Hybrid Fund - Direct   Hybrid        0.3525
# 24   Kotak Multi Asset Allocation Fund - Direct   Hybrid        0.3307
# 25                  SBI Small Cap Fund - Direct   Equity        0.3295
# 26                    DSP Mid Cap Fund - Direct   Equity        0.1614
# 27        Kotak Aggressive Hybrid Fund - Direct   Hybrid        0.1474
# 28    Axis Multi Asset Allocation Fund - Direct   Hybrid        0.0537
# 29  Nippon Multi Asset Allocation Fund - Direct   Hybrid       -0.0451
# 30        Tata Balanced Advantage Fund - Direct   Hybrid       -0.1105
# 31           ICICI Corporate Bond Fund - Direct     Debt       -0.1747
# 32               Tata Liquid Fund Fund - Direct     Debt       -0.4149
# 33             Aditya Liquid Fund Fund - Direct     Debt       -0.4323
# 34                Kotak Gilt Fund Fund - Direct     Debt       -0.4698
# 35                  SBI Large Cap Fund - Direct   Equity       -0.4998
# 36                 HDFC Gilt Fund Fund - Direct     Debt       -0.5162
# 37             UTI Corporate Bond Fund - Direct     Debt       -0.5342
# 38                 Axis Gilt Fund Fund - Direct     Debt       -0.7496
# 39                 Axis Gilt Fund Fund - Direct     Debt       -0.8991
# 40                SBI Liquid Fund Fund - Direct     Debt       -0.9267
#
#     sortino_ratio
# 1          2.0304
# 2          1.6937
# 3          1.5847
# 4          1.4731
# 5          1.5279
# 6          1.5477
# 7          1.4608
# 8          1.4176
# 9          1.3208
# 10         1.1278
# 11         0.9255
# 12         0.9251
# 13         0.9200
# 14         0.8864
# 15         0.8570
# 16         0.8699
# 17         0.8823
# 18         0.7532
# 19         0.7389
# 20         0.6869
# 21         0.6859
# 22         0.6010
# 23         0.5864
# 24         0.5608
# 25         0.5233
# 26         0.2677
# 27         0.2441
# 28         0.0909
# 29        -0.0792
# 30        -0.1834
# 31        -0.2957
# 32        -0.7117
# 33        -0.7080
# 34        -0.7922
# 35        -0.8285
# 36        -0.8516
# 37        -0.9186
# 38        -1.2547
# 39        -1.5015
# 40        -1.6286

# %% [markdown]
# ## 5. Sortino Ratio
# `Sortino = (Rp − Rf) / σ_downside × √252`
#
# The Sortino ratio penalises only downside volatility. Funds with a high Sortino but moderate Sharpe have well-controlled drawdown behaviour.

# %%
df_sortino = df_metrics[["scheme_name","category","sharpe_ratio","sortino_ratio"]].sort_values("sortino_ratio", ascending=False).reset_index(drop=True)
df_sortino.index += 1

# Scatter: Sharpe vs Sortino coloured by category
color_map = {"Equity": "#1976D2", "Hybrid": "#388E3C", "Debt": "#F57C00"}
colors_sc = [color_map[c] for c in df_sortino["category"]]

fig, ax = plt.subplots(figsize=(10, 7))
ax.scatter(df_sortino["sharpe_ratio"], df_sortino["sortino_ratio"], c=colors_sc, s=80, alpha=0.85)
ax.axline((0, 0), slope=1, color="grey", lw=1, linestyle="--", label="Sortino = Sharpe line")
ax.set_xlabel("Sharpe Ratio"); ax.set_ylabel("Sortino Ratio")
ax.set_title("Sharpe vs Sortino Ratio — All 40 Funds")
patches = [mpatches.Patch(color=v, label=k) for k, v in color_map.items()]
ax.legend(handles=patches)
plt.tight_layout(); plt.show()

df_sortino.head(10)
# Out:
#                                scheme_name category  sharpe_ratio  \
# 1               DSP Sectoral Fund - Direct   Equity        1.2056
# 2   ICICI Balanced Advantage Fund - Direct   Hybrid        0.9740
# 3              Tata Sectoral Fund - Direct   Equity        0.9541
# 4      DSP Aggressive Hybrid Fund - Direct   Hybrid        0.8927
# 5        HDFC Corporate Bond Fund - Direct     Debt        0.8931
# 6     UTI Balanced Advantage Fund - Direct   Hybrid        0.9211
# 7      UTI Aggressive Hybrid Fund - Direct   Hybrid        0.8713
# 8   Aditya Aggressive Hybrid Fund - Direct   Hybrid        0.8565
# 9              Axis Sectoral Fund - Direct   Equity        0.8136
# 10   HDFC Balanced Advantage Fund - Direct   Hybrid        0.6901
#
#     sortino_ratio
# 1          2.0304
# 2          1.6937
# 3          1.5847
# 4          1.5477
# 5          1.5279
# 6          1.4731
# 7          1.4608
# 8          1.4176
# 9          1.3208
# 10         1.1278

# %% [markdown]
# ## 6. Alpha & Beta — OLS Regression on Nifty 100
# `Fund_return = α + β × Nifty100_return + ε`
# `Alpha (annualised) = intercept × 252`
#
# - **Beta > 1** → More volatile than the index (amplified market moves)
# - **Positive Alpha** → Consistent excess return above the benchmark

# %%
df_ab = df_metrics[["scheme_name","category","alpha","beta","tracking_error_nifty100","scorecard"]].copy()
df_ab = df_ab.sort_values("alpha", ascending=False).reset_index(drop=True)
df_ab.index += 1; df_ab.index.name = "alpha_rank"

# Scatter: Alpha vs Beta, sized by |TE|, coloured by category
color_map = {"Equity": "#1976D2", "Hybrid": "#388E3C", "Debt": "#F57C00"}
colors_sc = [color_map[c] for c in df_ab["category"]]
sizes = (df_ab["tracking_error_nifty100"].abs() * 10).clip(lower=30, upper=300)

fig, ax = plt.subplots(figsize=(11, 7))
sc = ax.scatter(df_ab["beta"], df_ab["alpha"], c=colors_sc, s=sizes, alpha=0.85)
ax.axhline(0, color="grey", lw=0.9, linestyle="--")
ax.axvline(1, color="grey", lw=0.9, linestyle=":")
ax.set_xlabel("Beta (vs Nifty 100)"); ax.set_ylabel("Alpha (% annualised)")
ax.set_title("Alpha vs Beta — 40 Mutual Fund Schemes\n(bubble size ∝ Tracking Error vs Nifty 100)")
patches = [mpatches.Patch(color=v, label=k) for k, v in color_map.items()]
ax.legend(handles=patches, loc="upper left")
# Annotate top-5 alpha generators
for _, row in df_ab.head(5).iterrows():
    ax.annotate(row["scheme_name"].split()[0], (row["beta"], row["alpha"]),
                fontsize=7, ha="left", va="bottom",
                color="white" if row["alpha"] > 0 else "red")
plt.tight_layout(); plt.show()

print("\nAlpha & Beta Table (top 10 by Alpha):")
df_ab.head(10)
# Out:
# C:\Users\rawat\AppData\Local\Temp\ipykernel_17112\117102757.py:23: UserWarning: Glyph 8733 (\N{PROPORTIONAL TO}) missing from font(s) Arial.
#   plt.tight_layout(); plt.show()
# C:\Users\rawat\AppData\Roaming\Python\Python314\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 8733 (\N{PROPORTIONAL TO}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# Alpha & Beta Table (top 10 by Alpha):
#                                        scheme_name category  alpha    beta  \
# alpha_rank
# 1                       DSP Sectoral Fund - Direct   Equity  15.62  1.2622
# 2                      Tata Sectoral Fund - Direct   Equity  13.03  0.7771
# 3                      Axis Sectoral Fund - Direct   Equity  11.43  0.6930
# 4             UTI Balanced Advantage Fund - Direct   Hybrid  10.06  0.4504
# 5           ICICI Balanced Advantage Fund - Direct   Hybrid   9.90  0.5390
# 6              UTI Aggressive Hybrid Fund - Direct   Hybrid   9.43  0.4588
# 7           Aditya Aggressive Hybrid Fund - Direct   Hybrid   8.72  0.4782
# 8              DSP Aggressive Hybrid Fund - Direct   Hybrid   7.78  0.6393
# 9            HDFC Balanced Advantage Fund - Direct   Hybrid   7.06  0.4526
# 10               HDFC Corporate Bond Fund - Direct     Debt   6.03  0.2737
#
#             tracking_error_nifty100  scorecard
# alpha_rank
# 1                             19.37      76.38
# 2                             18.69      70.38
# 3                             19.65      84.88
# 4                             13.82      83.25
# 5                             13.29      75.38
# 6                             13.69      78.62
# 7                             13.62      72.75
# 8                             12.25      81.38
# 9                             13.38      82.88
# 10                            10.93      63.25

# %% [markdown]
# ## 7. Maximum Drawdown
# `Max Drawdown = min(NAV_t / running_max(NAV) − 1)`
#
# The largest peak-to-trough decline. We also report the worst-drawdown date range for each fund.

# %%
df_dd = df_metrics[["scheme_name","category","max_drawdown","drawdown_start","drawdown_end"]].copy()
df_dd = df_dd.sort_values("max_drawdown").reset_index(drop=True)   # most negative first
df_dd.index += 1; df_dd.index.name = "dd_rank"

# Horizontal bar — worst 15
worst15 = df_dd.head(15)
fig, ax = plt.subplots(figsize=(13, 6))
colors_dd = ["#C62828" if c == "Equity" else "#558B2F" if c == "Hybrid" else "#E65100"
             for c in worst15["category"]]
ax.barh(range(len(worst15)), worst15["max_drawdown"], color=colors_dd)
ax.set_yticks(range(len(worst15)))
ax.set_yticklabels([n[:45] for n in worst15["scheme_name"]], fontsize=9)
ax.set_xlabel("Maximum Drawdown (%)")
ax.set_title("15 Worst Maximum Drawdowns Across 40 Funds")
ax.invert_yaxis()
ax.axvline(-20, color="yellow", lw=0.9, linestyle="--", label="−20% threshold")
ax.legend()
plt.tight_layout(); plt.show()

df_dd.head(15)
# Out:
#                                          scheme_name category  max_drawdown  \
# dd_rank
# 1                        SBI Large Cap Fund - Direct   Equity        -56.49
# 2                          DSP Mid Cap Fund - Direct   Equity        -47.94
# 3                      ICICI Large Cap Fund - Direct   Equity        -44.38
# 4                        UTI Small Cap Fund - Direct   Equity        -42.58
# 5         Kotak Multi Asset Allocation Fund - Direct   Hybrid        -40.74
# 6                        SBI Small Cap Fund - Direct   Equity        -38.17
# 7                       Nippon Mid Cap Fund - Direct   Equity        -37.94
# 8          Axis Multi Asset Allocation Fund - Direct   Hybrid        -35.83
# 9                        Axis Sectoral Fund - Direct   Equity        -33.79
# 10                      Tata Large Cap Fund - Direct   Equity        -33.29
# 11             Tata Balanced Advantage Fund - Direct   Hybrid        -32.07
# 12       Nippon Multi Asset Allocation Fund - Direct   Hybrid        -29.50
# 13                        HDFC Mid Cap Fund - Direct   Equity        -28.19
# 14                     Aditya Sectoral Fund - Direct   Equity        -28.18
# 15                     Kotak Small Cap Fund - Direct   Equity        -26.31
#
#         drawdown_start drawdown_end
# dd_rank
# 1           2021-12-17   2025-01-14
# 2           2022-03-22   2024-07-02
# 3           2022-06-02   2024-05-03
# 4           2022-06-22   2024-05-06
# 5           2022-06-29   2024-07-09
# 6           2022-06-22   2025-02-27
# 7           2023-10-23   2024-07-09
# 8           2022-07-12   2023-07-11
# 9           2022-06-29   2024-05-02
# 10          2022-03-30   2022-10-17
# 11          2025-02-19   2026-06-19
# 12          2022-03-24   2023-09-15
# 13          2022-04-13   2022-11-24
# 14          2023-11-06   2024-07-09
# 15          2024-12-11   2025-07-21

# %% [markdown]
# ## 8. Fund Scorecard (0 – 100)
# Composite weighted rank score:
#
# | Weight | Metric |
# |--------|--------|
# | 30% | 3-Year CAGR rank |
# | 25% | Sharpe Ratio rank |
# | 20% | Alpha rank |
# | 15% | Expense Ratio rank (inverse — lower is better) |
# | 10% | Max Drawdown rank (inverse — less negative is better) |

# %%
df_scorecard = df_metrics[["scheme_code","scheme_name","category","expense_ratio",
                            "cagr_1y","cagr_3y","cagr_5y","sharpe_ratio","sortino_ratio",
                            "alpha","max_drawdown","scorecard"]].copy()
df_scorecard = df_scorecard.sort_values("scorecard", ascending=False).reset_index(drop=True)
df_scorecard.index += 1; df_scorecard.index.name = "rank"

# Lollipop chart
fig, ax = plt.subplots(figsize=(14, 9))
colors_lp = ["#1565C0" if c == "Equity" else "#2E7D32" if c == "Hybrid" else "#E65100"
             for c in df_scorecard["category"]]
ax.hlines(df_scorecard.index, 0, df_scorecard["scorecard"], color=colors_lp, linewidth=1.2, alpha=0.7)
ax.scatter(df_scorecard["scorecard"], df_scorecard.index, c=colors_lp, s=50, zorder=5)
ax.set_yticks(df_scorecard.index)
ax.set_yticklabels([n[:48] for n in df_scorecard["scheme_name"]], fontsize=8)
ax.set_xlabel("Composite Scorecard (0 – 100)")
ax.set_title("Fund Scorecard Ranking — All 40 Schemes")
ax.invert_yaxis()
ax.axvline(50, color="grey", lw=0.8, linestyle="--", label="Score = 50")
patches = [mpatches.Patch(color="#1565C0", label="Equity"),
           mpatches.Patch(color="#2E7D32", label="Hybrid"),
           mpatches.Patch(color="#E65100", label="Debt")]
ax.legend(handles=patches, loc="lower right")
plt.tight_layout(); plt.show()

df_scorecard
# Out:
#       scheme_code                                  scheme_name category  \
# rank
# 1          100025                  Axis Sectoral Fund - Direct   Equity
# 2          100009         UTI Balanced Advantage Fund - Direct   Hybrid
# 3          100012        HDFC Balanced Advantage Fund - Direct   Hybrid
# 4          100027          DSP Aggressive Hybrid Fund - Direct   Hybrid
# 5          100039          UTI Aggressive Hybrid Fund - Direct   Hybrid
# 6          100007                   DSP Sectoral Fund - Direct   Equity
# 7          100033       ICICI Balanced Advantage Fund - Direct   Hybrid
# 8          100018       Aditya Aggressive Hybrid Fund - Direct   Hybrid
# 9          100010                  Tata Sectoral Fund - Direct   Equity
# 10         100022                   HDFC Mid Cap Fund - Direct   Equity
# 11         100016                Kotak Small Cap Fund - Direct   Equity
# 12         100003        ICICI Aggressive Hybrid Fund - Direct   Hybrid
# 13         100013                ICICI Large Cap Fund - Direct   Equity
# 14         100028                Aditya Sectoral Fund - Direct   Equity
# 15         100032            HDFC Corporate Bond Fund - Direct     Debt
# 16         100004                 Nippon Mid Cap Fund - Direct   Equity
# 17         100040                 Tata Large Cap Fund - Direct   Equity
# 18         100014               Nippon Gilt Fund Fund - Direct     Debt
# 19         100015    Axis Multi Asset Allocation Fund - Direct   Hybrid
# 20         100034                 Nippon Mid Cap Fund - Direct   Equity
# 21         100023           ICICI Corporate Bond Fund - Direct     Debt
# 22         100020               Tata Liquid Fund Fund - Direct     Debt
# 23         100008             Aditya Liquid Fund Fund - Direct     Debt
# 24         100026                Kotak Gilt Fund Fund - Direct     Debt
# 25         100036   Kotak Multi Asset Allocation Fund - Direct   Hybrid
# 26         100017                  DSP Gilt Fund Fund - Direct     Debt
# 27         100035                 Axis Gilt Fund Fund - Direct     Debt
# 28         100006        Kotak Aggressive Hybrid Fund - Direct   Hybrid
# 29         100024  Nippon Multi Asset Allocation Fund - Direct   Hybrid
# 30         100019                  UTI Small Cap Fund - Direct   Equity
# 31         100037                    DSP Mid Cap Fund - Direct   Equity
# 32         100038             Aditya Liquid Fund Fund - Direct     Debt
# 33         100011                SBI Liquid Fund Fund - Direct     Debt
# 34         100029             UTI Corporate Bond Fund - Direct     Debt
# 35         100030        Tata Balanced Advantage Fund - Direct   Hybrid
# 36         100005                 Axis Gilt Fund Fund - Direct     Debt
# 37         100021          SBI Aggressive Hybrid Fund - Direct   Hybrid
# 38         100002                 HDFC Gilt Fund Fund - Direct     Debt
# 39         100001                  SBI Small Cap Fund - Direct   Equity
# 40         100031                  SBI Large Cap Fund - Direct   Equity
#
#       expense_ratio  cagr_1y  cagr_3y  cagr_5y  sharpe_ratio  sortino_ratio  \
# rank
# 1              1.17    26.90    29.45    21.73        0.8136         1.3208
# 2              0.59    12.37    18.83    20.79        0.9211         1.4731
# 3              0.16    22.77    22.86    16.09        0.6901         1.1278
# 4              0.68    16.78    21.24    20.62        0.8927         1.5477
# 5              1.35     7.07    27.73    18.87        0.8713         1.4608
# 6              1.48    19.67    10.43    32.77        1.2056         2.0304
# 7              1.98    21.57    18.95    21.91        0.9740         1.6937
# 8              0.25    10.43     8.06    20.43        0.8565         1.4176
# 9              2.18    -1.27    10.78    30.52        0.9541         1.5847
# 10             0.94    42.28    18.65    18.59        0.5165         0.8864
# 11             1.42    12.13     9.22    13.21        0.5484         0.9251
# 12             1.37    16.89    13.24    10.37        0.5460         0.9200
# 13             0.75    19.74    23.05    15.07        0.4248         0.6869
# 14             1.70     2.10    13.77    17.17        0.5688         0.9255
# 15             1.07     3.47     6.71    11.09        0.8931         1.5279
# 16             0.47    13.18     8.93    14.00        0.5139         0.8570
# 17             0.73    44.89    11.46    15.37        0.4511         0.7389
# 18             0.97     5.51     9.14     9.08        0.5022         0.8823
# 19             1.08     3.08    13.35     4.76        0.0537         0.0909
# 20             1.64    -2.73     3.87    16.46        0.5111         0.8699
# 21             0.35     6.57     6.33     4.83       -0.1747        -0.2957
# 22             0.28     4.27     5.88     4.49       -0.4149        -0.7117
# 23             2.14     6.38     6.96     7.93        0.3709         0.6010
# 24             0.51     6.19     3.18     4.85       -0.4698        -0.7922
# 25             1.22    -0.65    -1.00     6.14        0.3307         0.5608
# 26             2.17     3.49     4.44     8.40        0.4008         0.6859
# 27             0.33     1.85     4.66     3.53       -0.7496        -1.2547
# 28             1.38     3.03     2.84     7.92        0.1474         0.2441
# 29             1.55     8.93     4.93     4.09       -0.0451        -0.0792
# 30             1.54   -10.14     0.93    10.77        0.4601         0.7532
# 31             0.82   -20.47    -1.76     6.70        0.1614         0.2677
# 32             0.71    -2.21     1.68     3.47       -0.4323        -0.7080
# 33             0.77     0.88     1.84     2.99       -0.9267        -1.6286
# 34             1.22    -0.45     2.26     2.89       -0.5342        -0.9186
# 35             1.31   -28.31    -4.59     4.04       -0.1105        -0.1834
# 36             1.09     2.74     1.74     2.26       -0.8991        -1.5015
# 37             2.13   -12.97    -2.99     8.62        0.3525         0.5864
# 38             1.65     4.42     2.33     3.84       -0.5162        -0.8516
# 39             1.78    -2.33    -6.58     7.92        0.3295         0.5233
# 40             2.14    15.88    -2.91    -8.28       -0.4998        -0.8285
#
#       alpha  max_drawdown  scorecard
# rank
# 1     11.43        -33.79      84.88
# 2     10.06        -14.26      83.25
# 3      7.06        -17.00      82.88
# 4      7.78        -14.42      81.38
# 5      9.43        -15.40      78.62
# 6     15.62        -25.88      76.38
# 7      9.90        -15.99      75.38
# 8      8.72        -12.23      72.75
# 9     13.03        -24.91      70.38
# 10     1.63        -28.19      69.38
# 11     5.14        -26.31      64.38
# 12     3.09        -22.66      64.25
# 13    -4.77        -44.38      64.00
# 14     1.78        -28.18      64.00
# 15     6.03         -4.77      63.25
# 16     1.54        -18.29      62.88
# 17     0.10        -33.29      62.50
# 18     4.42         -6.43      58.62
# 19    -3.00        -35.83      51.25
# 20     0.17        -37.94      48.12
# 21     1.40         -6.83      47.25
# 22     2.07         -5.23      47.12
# 23     3.52         -6.49      44.94
# 24     2.25         -6.24      41.38
# 25     1.17        -40.74      40.94
# 26     4.84         -4.38      40.00
# 27     0.04         -8.13      38.50
# 28     0.05        -25.12      37.62
# 29    -2.08        -29.50      36.88
# 30    -3.33        -42.58      35.88
# 31   -13.18        -47.94      34.00
# 32    -0.97         -6.82      30.38
# 33     0.14         -5.19      27.88
# 34    -0.27         -6.56      26.56
# 35    -2.50        -32.07      26.12
# 36    -0.88         -7.27      25.00
# 37    -2.49        -23.48      24.88
# 38    -1.49        -12.27      24.00
# 39    -6.63        -38.17      23.62
# 40   -16.64        -56.49      18.56

# %% [markdown]
# ## 9. Benchmark Comparison — Top 5 vs Nifty 50 & Nifty 100 (3-Year)
# `Tracking Error = Std(R_fund − R_benchmark) × √252`
#
# A lower tracking error means the fund moves closely with the benchmark.

# %%
START_3Y = pd.Timestamp("2023-06-30")
END_3Y   = pd.Timestamp("2026-06-30")

top5 = df_metrics.sort_values("scorecard", ascending=False).head(5)
COLORS = ["#2196F3","#FF5722","#4CAF50","#9C27B0","#FF9800"]

df_nav_3y   = df_nav[(df_nav["date"] >= START_3Y) & (df_nav["date"] <= END_3Y)]
df_bench_3y = df_benchmarks[(df_benchmarks["date"] >= START_3Y) & (df_benchmarks["date"] <= END_3Y)].copy().sort_values("date")

# Cumulative returns
bench_s50  = df_bench_3y["nifty_50"].iloc[0]
bench_s100 = df_bench_3y["nifty_100"].iloc[0]
df_bench_3y["nifty50_cum"]  = (df_bench_3y["nifty_50"]  / bench_s50  - 1) * 100
df_bench_3y["nifty100_cum"] = (df_bench_3y["nifty_100"] / bench_s100 - 1) * 100

fig, ax = plt.subplots(figsize=(15, 7))
for i, (_, row) in enumerate(top5.iterrows()):
    code_val = row["scheme_code"]
    df_f = df_nav_3y[df_nav_3y["amfi_code"] == code_val].sort_values("date")
    if df_f.empty: continue
    cum = (df_f["nav"] / df_f["nav"].iloc[0] - 1) * 100
    label = f"{row['scheme_name'][:35]}  [Score={row['scorecard']:.0f}]"
    ax.plot(df_f["date"], cum, color=COLORS[i], lw=2, label=label)

ax.plot(df_bench_3y["date"], df_bench_3y["nifty50_cum"],  "w--", lw=2,   label="Nifty 50")
ax.plot(df_bench_3y["date"], df_bench_3y["nifty100_cum"], "grey", lw=1.8, linestyle=":", label="Nifty 100")

ax.set_xlabel("Date"); ax.set_ylabel("Cumulative Return (%)")
ax.set_title("Top-5 Fund Performance vs Benchmarks  |  3-Year Window (Jun 2023 – Jun 2026)", fontsize=13)
ax.legend(fontsize=8, loc="upper left")
ax.grid(axis="y", alpha=0.3)
plt.tight_layout(); plt.show()

# Tracking Error table
print("\nTracking Error Summary:")
te_table = top5[["scheme_name","tracking_error_nifty50","tracking_error_nifty100","scorecard"]].reset_index(drop=True)
te_table.index += 1
te_table.columns = ["Scheme","TE vs Nifty 50 (%)","TE vs Nifty 100 (%)","Scorecard"]
print(te_table.to_string())
# Out:
# Tracking Error Summary:
#                                   Scheme  TE vs Nifty 50 (%)  TE vs Nifty 100 (%)  Scorecard
# 1            Axis Sectoral Fund - Direct               19.47                19.65      84.88
# 2   UTI Balanced Advantage Fund - Direct               13.58                13.82      83.25
# 3  HDFC Balanced Advantage Fund - Direct               13.25                13.38      82.88
# 4    DSP Aggressive Hybrid Fund - Direct               12.11                12.25      81.38
# 5    UTI Aggressive Hybrid Fund - Direct               13.46                13.69      78.62

# %% [markdown]
# ## 10. Deliverables
#
# | File | Location | Description |
# |------|----------|-------------|
# | `Performance_Analytics.ipynb` | `notebooks/` | This notebook |
# | `fund_scorecard.csv` | `reports/` | All 40 funds ranked by composite scorecard |
# | `alpha_beta.csv` | `reports/` | Alpha, Beta, Tracking Error for all funds |
# | `benchmark_comparison_chart.png` | `reports/` | High-resolution PNG of top-5 vs benchmarks |
